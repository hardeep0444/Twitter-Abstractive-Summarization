# %% [markdown]
# # Header Files

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from langdetect import detect
import re
import emoji
from transformers import PegasusForConditionalGeneration, PegasusTokenizer

# %% [markdown]
# # Making Groups of 10 Tweets of English Language

# %%
def ten_in_a_group(x,n):
    df = []
    count = 0
    tweets = ""

    for i in range(n):
        if(detect(x['text'][i])=='en'):
            count=count+1
            tweets = tweets+x['text'][i]
        if(count==10):
            count=0
            df.append(tweets)
            tweets=""
    return df

# %% [markdown]
# # Text Preprocessing

# %%
punctuations = "!”$%&’()*+-/:;<=>[]^_`{|}~•@#"

def remove_punctuations(x):
    return x.translate(str.maketrans('','',punctuations))

def remove_urls(x):
    return re.sub('http://\S+|https://\S+', '', x)

def remove_escape_sequences(x):
    return x.replace("\n","")

def remove_ampersand(x):
    return x.replace("&", "and")

def remove_hashtags(x):
    return re.sub('#[A-Za-z0-9]','',x)

# %%
def preprocessing(x,n):
    for i in range(n):
        x['text'][i] = remove_urls(x['text'][i])
        x['text'][i] = remove_punctuations(x['text'][i])
        x['text'][i] = remove_hashtags(x['text'][i])  
        x['text'][i] = remove_escape_sequences(x['text'][i])
        x['text'][i] = remove_ampersand(x['text'][i])
        x['text'][i] = emoji.demojize(x['text'][i])

# %% [markdown]
# ## AYODHYAVERDICT

# %%
data_1 = pd.read_csv("#AYODHYAVERDICT_tweets.csv")
data_1
# Out:
#                   user_id             status_id           created_at  \
# 0    x1179280919263186944  x1193844270861410306  2019-11-11 10:53:49
# 1    x1179280919263186944  x1193844191891087360  2019-11-11 10:53:30
# 2             x1113627067  x1193844257012011008  2019-11-11 10:53:46
# 3    x1027888044307701761  x1193844250963628032  2019-11-11 10:53:44
# 4     x762122872173191168  x1193844250661638145  2019-11-11 10:53:44
# ..                    ...                   ...                  ...
# 195            x179003453  x1193841884524949504  2019-11-11 10:44:20
# 196  x1095730132898246661  x1193841865541345280  2019-11-11 10:44:15
# 197             x21191906  x1193841865134465024  2019-11-11 10:44:15
# 198   x719049254774247424  x1193841829747146752  2019-11-11 10:44:07
# 199   x868341595917168640  x1193841810491052032  2019-11-11 10:44:02
#
#          screen_name                                               text  \
# 0    Prakash72091622  Ahead of #AyodhyaVerdict, appeal to everyone t...
# 1    Prakash72091622  We respect the Hon’ble Supreme Court’s #Ayodhy...
# 2        warewolf999  This is the last prayer offered at #BabriMasji...
# 3     Aayush74670776  “गिरा अरथ जल बीचि सम कहिअत भिन्न न भिन्न। \nबं...
# 4        akmohanty07  "There is a profound reason Maharshi Valmiki t...
# ..               ...                                                ...
# 195       chennak418  As a step to impress Sonia Gandhi&amp; Congres...
# 196      anu04706249  By #AYODHYAVERDICT,ALL pending issues like-#Tr...
# 197   UnityInDiverse  கோவில் கொள்ளைக்காரர்களின் கூடாரம்! ~ கலைஞர்\n\...
# 198     MALLERSOWMYA  Just bcoz BJP got 303 seats in LS everything l...
# 199      luvmeimfaiz  That's Barrister @asadowaisi . Your name will ...
#
#                   source  display_text_width reply_to_status_id  \
# 0        Twitter Web App                 140                NaN
# 1        Twitter Web App                 139                NaN
# 2    Twitter for Android                 140                NaN
# 3    Twitter for Android                 138                NaN
# 4     Twitter for iPhone                 140                NaN
# ..                   ...                 ...                ...
# 195  Twitter for Android                 144                NaN
# 196      Twitter Web App                 144                NaN
# 197  Twitter for Android                 140                NaN
# 198  Twitter for Android                 144                NaN
# 199  Twitter for Android                 140                NaN
#
#     reply_to_user_id reply_to_screen_name  ...  statuses_count  \
# 0                NaN                  NaN  ...             897
# 1                NaN                  NaN  ...             897
# 2                NaN                  NaN  ...          105502
# 3                NaN                  NaN  ...            1007
# 4                NaN                  NaN  ...           16755
# ..               ...                  ...  ...             ...
# 195              NaN                  NaN  ...           24448
# 196              NaN                  NaN  ...             133
# 197              NaN                  NaN  ...           65343
# 198              NaN                  NaN  ...          138538
# 199              NaN                  NaN  ...             558
#
#      favourites_count   account_created_at  verified              profile_url  \
# 0                1241  2019-10-02 06:24:44     False                      NaN
# 1                1241  2019-10-02 06:24:44     False                      NaN
# 2                2628  2013-01-23 06:21:07     False  https://t.co/twxHxOtlG0
# 3                 788  2018-08-10 12:03:01     False                      NaN
# 4               57989  2016-08-07 03:07:07     False                      NaN
# ..                ...                  ...       ...                      ...
# 195             27433  2010-08-16 07:13:47     False                      NaN
# 196                19  2019-02-13 17:03:16     False                      NaN
# 197             14349  2009-02-18 12:43:11     False                      NaN
# 198            139304  2016-04-10 06:27:56     False                      NaN
# 199               974  2017-05-27 05:42:24     False  https://t.co/65S2HYg4jP
#
#                                profile_expanded_url account_lang  \
# 0                                               NaN          NaN
# 1                                               NaN          NaN
# 2                             http://www.google.com          NaN
# 3                                               NaN          NaN
# 4                                               NaN          NaN
# ..                                              ...          ...
# 195                                             NaN          NaN
# 196                                             NaN          NaN
# 197                                             NaN          NaN
# 198                                             NaN          NaN
# 199  https://www.facebook.com/pg/luvmeimfaiz/about/          NaN
#
#                                     profile_banner_url  \
# 0                                                  NaN
# 1                                                  NaN
# 2    https://pbs.twimg.com/profile_banners/11136270...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195                                                NaN
# 196                                                NaN
# 197  https://pbs.twimg.com/profile_banners/21191906...
# 198  https://pbs.twimg.com/profile_banners/71904925...
# 199  https://pbs.twimg.com/profile_banners/86834159...
#
#                                profile_background_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2    http://abs.twimg.com/images/themes/theme5/bg.gif
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 195  http://abs.twimg.com/images/themes/theme1/bg.png
# 196                                               NaN
# 197  http://abs.twimg.com/images/themes/theme4/bg.gif
# 198                                               NaN
# 199                                               NaN
#
#                                      profile_image_url
# 0    http://pbs.twimg.com/profile_images/1179284199...
# 1    http://pbs.twimg.com/profile_images/1179284199...
# 2    http://pbs.twimg.com/profile_images/1000440223...
# 3    http://pbs.twimg.com/profile_images/1027888890...
# 4    http://pbs.twimg.com/profile_images/7665359093...
# ..                                                 ...
# 195  http://pbs.twimg.com/profile_images/1133588918...
# 196  http://abs.twimg.com/sticky/default_profile_im...
# 197  http://pbs.twimg.com/profile_images/1014359338...
# 198  http://pbs.twimg.com/profile_images/8692152758...
# 199  http://pbs.twimg.com/profile_images/1193257285...
#
# [200 rows x 88 columns]

# %%
df_1 = ten_in_a_group(data_1,data_1.shape[0])

# %%
df_1 = pd.DataFrame(df_1, columns=['text'])

# %%
preprocessing(df_1,df_1.shape[0])

# %%
df_1.shape
# Out:
# (12, 1)

# %% [markdown]
# ## INDvAUS

# %%
data_2 = pd.read_csv("#INDvAUS.csv")

# %%
data_2
# Out:
#       Unnamed: 0                                               text
# 0              0  #INDvAUS #IndvsAus #BorderGavaskarTrophy2023 h...
# 1              1  Scenes in 1st inning of 3rd test\n#indvaus #IN...
# 2              2                   #INDvAUS https://t.co/E9kuupAiau
# 3              3                   #INDvAUS https://t.co/O1doRsFIDc
# 4              4  @GBNEWS @joshxhowie @LeoKearse The #quran lite...
# ...          ...                                                ...
# 997          997  I think KL Rahul was acting as sink of Bad Luc...
# 998          998  IND vs AUS: मैथ्यू हेडन ने लाइव कमेंट्री के दौ...
# 999          999  #INDvAUS के बीच चल रही #BorderGavaskarTrophy20...
# 1000        1000  @Brad_Hogg Can anyone give stats on which coun...
# 1001        1001  @sports_tak every one talked about Pak pitches...
#
# [1002 rows x 2 columns]

# %%
df_2 = ten_in_a_group(data_2,data_2.shape[0])

# %%
df_2 = pd.DataFrame(df_2, columns=['text'])

# %%
preprocessing(df_2,df_2.shape[0])

# %%
df_2.shape
# Out:
# (78, 1)

# %% [markdown]
# ## Adani

# %%
data_3 = pd.read_csv("#Adani.csv")
data_3
# Out:
#       Unnamed: 0                                               text
# 0              0  #harshrajput #adani #DATING 4/4 thread\n#salon...
# 1              1  #harshrajput #adani #DATING 3/4 thread\n#salon...
# 2              2  #harshrajput #adani #DATING 2/4 thread\n#salon...
# 3              3  #harshrajput #adani #DATING 1/4 thread\n#salon...
# 4              4  #TotalEnergies, paid $2 billion for #AdaniGree...
# ...          ...                                                ...
# 997          997  @yadavakhilesh . #Adani के शेयरों में जो देश क...
# 998          998  @yadavakhilesh . #Adani के शेयरों में जो देश क...
# 999          999  . #Adani के शेयरों में जो देश की जनता का पैसा ...
# 1000        1000  10 Straight Day of NIFTY in negative.\nWhat’s ...
# 1001        1001  @ElvishYadav अच्छी बात है। हिंदुओं के लिए बोलत...
#
# [1002 rows x 2 columns]

# %%
df_3 = ten_in_a_group(data_3,data_3.shape[0])
df_3 = pd.DataFrame(df_3, columns=['text'])
preprocessing(df_3,df_3.shape[0])

# %%
df_3.shape
# Out:
# (67, 1)

# %% [markdown]
# ## Forbes

# %%
data_4 = pd.read_csv("#forbes.csv")
data_4
# Out:
#       Unnamed: 0                                               text
# 0              0  #Saudi #Aramco has completed the acquisition o...
# 1              1  「すべての物にはヒビがある。\n　そして、そこから光は入る。」\n\n#オードリー・タン の...
# 2              2  10 Creative #TikTok Video Ideas For Brands (Wi...
# 3              3  Making money is an art, Working is an art, Bus...
# 4              4  @Forbes cited @FMI_Research from our report on...
# ...          ...                                                ...
# 997          997  RT:(@petapixel) Instagram alternative 100ASA n...
# 998          998  .@HindenburgRes के बाद अब @Forbes ने गौतम अड़ा...
# 999          999  15 Low-Budget Strategies For Increasing Cash F...
# 1000        1000  Social Start Now generates excitement through ...
# 1001        1001  Get the knowledge and tools you need to manage...
#
# [1002 rows x 2 columns]

# %%
df_4 = ten_in_a_group(data_4,data_4.shape[0])
df_4 = pd.DataFrame(df_4, columns=['text'])
preprocessing(df_4,df_4.shape[0])

# %%
df_4.shape
# Out:
# (81, 1)

# %% [markdown]
# ## BlackLivesMatter

# %%
data_5 = pd.read_csv("#BlackLivesMatter.csv")
data_5
# Out:
#       Unnamed: 0                                               text
# 0              0                                  #BlackLivesMatter
# 1              1  It's time to #DefundTheBurtonPolice #BlackLive...
# 2              2                     Sandra Bland #BlackLivesMatter
# 3              3  BP's forgotten pensioners\n  @DavidLammy @bbcn...
# 4              4  ding* DING. #PennState #BlackLivesMatter #Just...
# ...          ...                                                ...
# 997          997  ding DING? ding. Ding Ding ding #PennState #Bl...
# 998          998  #blackcrimesmatter #blacklivesmatter #hypocris...
# 999          999  https://t.co/yarYLRqJTE #neworleans \n#art #gi...
# 1000        1000  WHAT IS DONE IN THE DARK, SOON COMES TO THE LI...
# 1001        1001  This officer needs a raise!\n\n#blackcrimesmat...
#
# [1002 rows x 2 columns]

# %%
df_5 = ten_in_a_group(data_5,data_5.shape[0])
df_5 = pd.DataFrame(df_5, columns=['text'])
preprocessing(df_5,df_5.shape[0])

# %%
df_5.shape
# Out:
# (84, 1)

# %% [markdown]
# ## Bitcoin

# %%
data_6 = pd.read_csv("#Bitcoin.csv")
data_6
# Out:
#       Unnamed: 0                                               text
# 0              0  Już o 9:30 aktualizacja z rynku krypto i nie t...
# 1              1                   Fiat: All lies\n#Bitcoin: Allies
# 2              2  @MwahafarN The Wolfshack is looking amazing wi...
# 3              3  What’s happening?\n\nOur friend told us, that ...
# 4              4  The Sandbox acquires Germany’s Sviper to add m...
# ...          ...                                                ...
# 997          997              Julian Assange on #Bitcoin in 2014! 🤯
# 998          998  ...so you can have an overview of this emergin...
# 999          999  Gains aren't real until converted into #bitcoi...
# 1000        1000  Make your orders, we deliver fast to any locat...
# 1001        1001  Smart switch module with control temp. and mon...
#
# [1002 rows x 2 columns]

# %%
df_6 = ten_in_a_group(data_6,data_6.shape[0])
df_6 = pd.DataFrame(df_6, columns=['text'])
preprocessing(df_6,df_6.shape[0])

# %%
df_6.shape
# Out:
# (76, 1)

# %% [markdown]
# ## ChatGPT

# %%
data_7 = pd.read_csv("#ChatGPT.csv")
data_7
# Out:
#       Unnamed: 0                                               text
# 0              0  When you finally integrate #ChatGPT API into y...
# 1              1  My POV on the uses for ChatGPT: \n- No, it doe...
# 2              2  #ChatGPT のAPI ChatCompletion呼び出し、会話履歴も引数として投げる...
# 3              3  Blown away by this technology #ChatGPT #AI htt...
# 4              4  ✨ #ChatGPT  now opens its API! ✨ \n\nI've crea...
# ...          ...                                                ...
# 997          997  Me puse a jugar con #ChatGPT como si fuera Aki...
# 998          998  Prompt for copywriting 3 👇👉 https://t.co/xNzks...
# 999          999  🗞️Founder Of Bored Ape Yacht Club #YugaLabs Un...
# 1000        1000  Prompt for copywriting 4 👇👉 https://t.co/geQCk...
# 1001        1001  電源供給が無いのに自発的行動出来る生物ってすんげぇ by　AI   #タイムセール　#アマゾ...
#
# [1002 rows x 2 columns]

# %%
df_7 = ten_in_a_group(data_7,data_7.shape[0])
df_7 = pd.DataFrame(df_7, columns=['text'])
preprocessing(df_7,df_7.shape[0])

# %%
df_7.shape
# Out:
# (67, 1)

# %% [markdown]
# ## Tesla

# %%
data_8 = pd.read_csv("#Tesla.csv")
data_8
# Out:
#       Unnamed: 0                                               text
# 0              0  Master Plan 3 de #Tesla et Investor Day 2023, ...
# 1              1  #ElPaís @elpais_cultura #DigitalArt #Metaverse...
# 2              2  #Rareearth miners in #China fall #Thursday as ...
# 3              3  Ya chocaron esto??? \nBuena nota #Tesla #siete...
# 4              4  Wahoo! Someone was first to spot a 2021 Tesla ...
# ...          ...                                                ...
# 997          997  Say hello to the latest iteration of the Tesla...
# 998          998  Concamin reconoce apertura del Gobierno de #AM...
# 999          999  ⭕ La decisión de #Tesla de invertir 10 mil mdd...
# 1000        1000  ⭕ La decisión de #Tesla de invertir 10 mil mdd...
# 1001        1001  Para mí la mejor rola de #Tesla o no mi buen ⁦...
#
# [1002 rows x 2 columns]

# %%
df_8 = ten_in_a_group(data_8,data_8.shape[0])
df_8 = pd.DataFrame(df_8, columns=['text'])
preprocessing(df_8,df_8.shape[0])

# %%
df_8.shape
# Out:
# (40, 1)

# %% [markdown]
# ## ShutDownJNU_tweets

# %%
data_9 = pd.read_csv("#ShutDownJNU_tweets.csv")
data_9
# Out:
#                   user_id             status_id           created_at  \
# 0              x145914904  x1194250903894675456  2019-11-12 13:49:38
# 1     x999465582482223104  x1194250874291277825  2019-11-12 13:49:31
# 2              x592991019  x1194250853873594369  2019-11-12 13:49:26
# 3              x132134411  x1194250820184707072  2019-11-12 13:49:18
# 4              x134399710  x1194250813167689729  2019-11-12 13:49:16
# ..                    ...                   ...                  ...
# 195            x161189354  x1194247341336719360  2019-11-12 13:35:28
# 196   x734373707498590212  x1194247339478671360  2019-11-12 13:35:28
# 197           x3254322074  x1194247326585352192  2019-11-12 13:35:25
# 198  x1106594332751077376  x1194247322126802944  2019-11-12 13:35:24
# 199  x1048872445023645696  x1194247268905320448  2019-11-12 13:35:11
#
#          screen_name                                               text  \
# 0    1frm90Migration  We are poor people. \nWe cannot afford the hik...
# 1      Sunny74240064  Public won't mind funding college subsidies if...
# 2            vvbindu  □ 473 Teachers  \n□ 8309 Students \n□ 1276 Adm...
# 3     bharathkumarsk  Public won't mind funding college subsidies if...
# 4         frmchandan  For all those running the hashtag #ShutDownJNU...
# ..               ...                                                ...
# 195     kunalclinton  People who are trending #ShutDownJNU are the s...
# 196   Rajendrashaw16  आज जो लोग #shutdownjnu कह रहे हैं उन्हें ये पत...
# 197  natarrajanappu1  நக்சல் கூடாரமாக இருக்கும் JNU இழுத்து மூடுவது ...
# 198      Thik____Hai  Sambit Patra, Shazia Ilmi, Zafar Islam, Asifa ...
# 199  MohdIsr39387089  राम राज्य में मंदिर बनाये जाएंगे और स्कूल कॉले...
#
#                   source  display_text_width reply_to_status_id  \
# 0    Twitter for Android                 140                NaN
# 1    Twitter for Android                 140                NaN
# 2    Twitter for Android                 140                NaN
# 3     Twitter for iPhone                 140                NaN
# 4    Twitter for Android                 122                NaN
# ..                   ...                 ...                ...
# 195  Twitter for Android                 107                NaN
# 196      Twitter Web App                 140                NaN
# 197  Twitter for Android                 140                NaN
# 198  Twitter for Android                 140                NaN
# 199  Twitter for Android                 140                NaN
#
#     reply_to_user_id reply_to_screen_name  ...  statuses_count  \
# 0                NaN                  NaN  ...           25680
# 1                NaN                  NaN  ...           31412
# 2                NaN                  NaN  ...            3071
# 3                NaN                  NaN  ...           22360
# 4                NaN                  NaN  ...              73
# ..               ...                  ...  ...             ...
# 195              NaN                  NaN  ...            5977
# 196              NaN                  NaN  ...           26325
# 197              NaN                  NaN  ...          115397
# 198              NaN                  NaN  ...           16994
# 199              NaN                  NaN  ...             420
#
#      favourites_count   account_created_at  verified              profile_url  \
# 0               15616  2010-05-20 05:18:45     False  https://t.co/BF8dPMPgfI
# 1               43670  2018-05-24 01:42:18     False                      NaN
# 2                6072  2012-05-28 17:29:57     False                      NaN
# 3               30025  2010-04-12 11:11:28     False  https://t.co/twxHxObKhq
# 4                 306  2010-04-18 09:06:59     False  https://t.co/bhbZL0nzOC
# ..                ...                  ...       ...                      ...
# 195              8866  2010-06-30 06:05:52     False                      NaN
# 196             54945  2016-05-22 13:21:50     False                      NaN
# 197            128365  2015-06-24 05:22:07     False                      NaN
# 198             19197  2019-03-15 16:33:43     False                      NaN
# 199              1268  2018-10-07 09:47:32     False                      NaN
#
#                     profile_expanded_url account_lang  \
# 0    https://twitter.com/1frm90Migration          NaN
# 1                                    NaN          NaN
# 2                                    NaN          NaN
# 3            https://twitter.com/twitter          NaN
# 4                  http://frmchandan.com          NaN
# ..                                   ...          ...
# 195                                  NaN          NaN
# 196                                  NaN          NaN
# 197                                  NaN          NaN
# 198                                  NaN          NaN
# 199                                  NaN          NaN
#
#                                     profile_banner_url  \
# 0    https://pbs.twimg.com/profile_banners/14591490...
# 1                                                  NaN
# 2    https://pbs.twimg.com/profile_banners/59299101...
# 3    https://pbs.twimg.com/profile_banners/13213441...
# 4    https://pbs.twimg.com/profile_banners/13439971...
# ..                                                 ...
# 195  https://pbs.twimg.com/profile_banners/16118935...
# 196                                                NaN
# 197  https://pbs.twimg.com/profile_banners/32543220...
# 198                                                NaN
# 199                                                NaN
#
#                                 profile_background_url  \
# 0    http://abs.twimg.com/images/themes/theme18/bg.gif
# 1                                                  NaN
# 2     http://abs.twimg.com/images/themes/theme1/bg.png
# 3    http://abs.twimg.com/images/themes/theme19/bg.gif
# 4     http://abs.twimg.com/images/themes/theme8/bg.gif
# ..                                                 ...
# 195  http://abs.twimg.com/images/themes/theme14/bg.gif
# 196                                                NaN
# 197   http://abs.twimg.com/images/themes/theme1/bg.png
# 198                                                NaN
# 199                                                NaN
#
#                                      profile_image_url
# 0    http://pbs.twimg.com/profile_images/9605537582...
# 1    http://abs.twimg.com/sticky/default_profile_im...
# 2    http://pbs.twimg.com/profile_images/9237847147...
# 3    http://pbs.twimg.com/profile_images/1169315983...
# 4    http://pbs.twimg.com/profile_images/5092290817...
# ..                                                 ...
# 195  http://pbs.twimg.com/profile_images/9596554535...
# 196  http://pbs.twimg.com/profile_images/1192899773...
# 197  http://pbs.twimg.com/profile_images/6331602938...
# 198  http://pbs.twimg.com/profile_images/1113134293...
# 199  http://pbs.twimg.com/profile_images/1048876204...
#
# [200 rows x 88 columns]

# %%
df_9 = ten_in_a_group(data_9,data_9.shape[0])
df_9 = pd.DataFrame(df_9, columns=['text'])
preprocessing(df_9,df_9.shape[0])

# %%
df_9.shape
# Out:
# (14, 1)

# %% [markdown]
# ## KashmirFiles

# %%
data_10 = pd.read_csv("##KashmirFiles.csv")
data_10
# Out:
#       Unnamed: 0                                               text
# 0              0  @rupen_chowdhury Kashmiri Hindus ka pain unbea...
# 1              1  @mithunprabahar @woke_Kashmiri @ashoswai For m...
# 2              2  Thanks, @jamiatimes_in for giving the space to...
# 3              3  @MrSinha_ Remembering the words of #KashmirFil...
# 4              4  Shaheed Abdul Rashid dar,God willing, revoluti...
# ...          ...                                                ...
# 997          997  राजस्थान की कांग्रेस सरकार ने कश्मीरी पंडितों ...
# 998          998  राजस्थान की कांग्रेस सरकार ने कश्मीरी पंडितों ...
# 999          999  Copperware craft of #Kashmir\nThe copperware c...
# 1000        1000  राजस्थान की कांग्रेस सरकार ने कश्मीरी पंडितों ...
# 1001        1001  The Kashmir Files के निर्देशक Vivek Agnihotri ...
#
# [1002 rows x 2 columns]

# %%
df_10 = ten_in_a_group(data_10,data_10.shape[0])
df_10 = pd.DataFrame(df_10, columns=['text'])
preprocessing(df_10,df_10.shape[0])

# %%
df_10.shape
# Out:
# (64, 1)

# %% [markdown]
# ## Budget2023

# %%
data_11 = pd.read_csv("#Budget2023.csv")
data_11
# Out:
#       Unnamed: 0                                               text
# 0              0  मूलभूत सेवाओं पर निरंतर खर्च बढ़ा रही नीतीश सर...
# 1              1  @CanningsNDP Why don't you speak up for people...
# 2              2  While the #government has increased expenditur...
# 3              3  सोनीपत मेट्रोपॉलिटन डेवलपमेंट अथॉरिटी की स्थाप...
# 4              4  भाजप आमदार राम सातपुते यांनी शरद पवार यांचा एक...
# ...          ...                                                ...
# 997          997  ICAI Members' Journal The Chartered Accountant...
# 998          998  सर्वस्पर्शी बजट है, सभी वर्गों का ध्यान रखा जा...
# 999          999  #मध्य प्रदेश- के वित्त मंत्री जगदीश देवड़ा ने ...
# 1000        1000  #Budget2023 #MPEconomicSurvey #MP_budget #Bhop...
# 1001        1001  Madhya Pradesh Budget 2023: शिवराज सरकार का पे...
#
# [1002 rows x 2 columns]

# %%
df_11 = ten_in_a_group(data_11,data_11.shape[0])
df_11 = pd.DataFrame(df_11, columns=['text'])
preprocessing(df_11,df_11.shape[0])

# %%
df_11.shape
# Out:
# (49, 1)

# %% [markdown]
# ## Kohli

# %%
data_12 = pd.read_csv("#Kohli.csv")
data_12
# Out:
#       Unnamed: 0                                               text
# 0              0  Indian team didn't play spain bowling properly...
# 1              1  #BreakingNews #BorderGavaskarTrophy2023 #Kohli...
# 2              2  #news #BreakingNews #AajKiTaazaKhabar #topnews...
# 3              3  @daniel86cricket @BCCI Hey ! What's up  sister...
# 4              4  Once again, a disappointing result for Virat K...
# ...          ...                                                ...
# 997          997  Virat Kohli becomes the fastest to score 25,00...
# 998          998  Many more to go 😍😍😍 #Kohli #IndiavsAus https:/...
# 999          999  So Virat Kohli didn't score runs for a long ti...
# 1000        1000  King Kohli reaching another milestone, 25000 r...
# 1001        1001  #ViratKohli is fastest to 25,000 International...
#
# [1002 rows x 2 columns]

# %%
df_12 = ten_in_a_group(data_12,data_12.shape[0])
df_12 = pd.DataFrame(df_12, columns=['text'])
preprocessing(df_12,df_12.shape[0])

# %%
df_12.shape
# Out:
# (70, 1)

# %% [markdown]
# ## ShivSenaCheatsMaharashtra_tweets

# %%
data_13 = pd.read_csv("#ShivSenaCheatsMaharashtra_tweets.csv")
data_13
# Out:
#                   user_id             status_id           created_at  \
# 0             x4695772544  x1193972603464994816  2019-11-11 19:23:46
# 1    x1161565132754784258  x1193972599463636994  2019-11-11 19:23:45
# 2              x154257983  x1193972581121945600  2019-11-11 19:23:40
# 3     x757207454484692992  x1193972553921916928  2019-11-11 19:23:34
# 4     x757207454484692992  x1193971831927005184  2019-11-11 19:20:42
# ..                    ...                   ...                  ...
# 195   x769913375723692033  x1193970818625073152  2019-11-11 19:16:40
# 196            x101964419  x1193970817110986753  2019-11-11 19:16:40
# 197             x75953295  x1193970807891881984  2019-11-11 19:16:38
# 198           x2157045175  x1193970797217538053  2019-11-11 19:16:35
# 199           x3999666303  x1193970785322446848  2019-11-11 19:16:32
#
#          screen_name                                               text  \
# 0         jadhavdj11  Uddhav Thackrey’s 4 wrong assumptions: \n\n1. ...
# 1    InfidelApostate  Oh my goodness! Sheikh Hasina the Islamophobe....
# 2         ashu21ster  Shiv Sena quit NDA in the center even before s...
# 3      AshokSingh246  If BJP decides to abstain from voting, INC+NCP...
# 4      AshokSingh246  I was very excited about metro project in Pune...
# ..               ...                                                ...
# 195  nishankmishra77  Dear Maharashtra,\nYou might have 10 issues wi...
# 196    vipulkapadiya  महाराष्ट्र में वोटर के साथ शिवसेना का #MahaDho...
# 197     pratapsodhia  the people of #Maharashtra are never going to ...
# 198     amitpant1973  "न खुदा मिला न विसाले सनम. न इधर के रहे न उधर ...
# 199        Atom_Alok  Chalo sab log maandvali karke Raj Thackeray ko...
#
#                   source  display_text_width reply_to_status_id  \
# 0    Twitter for Android                 140                NaN
# 1    Twitter for Android                 259                NaN
# 2    Twitter for Android                 140                NaN
# 3     Twitter for iPhone                 139                NaN
# 4     Twitter for iPhone                 140                NaN
# ..                   ...                 ...                ...
# 195  Twitter for Android                 140                NaN
# 196  Twitter for Android                 140                NaN
# 197  Twitter for Android                 140                NaN
# 198  Twitter for Android                 140                NaN
# 199  Twitter for Android                 140                NaN
#
#     reply_to_user_id reply_to_screen_name  ...  statuses_count  \
# 0                NaN                  NaN  ...           27200
# 1                NaN                  NaN  ...            4843
# 2                NaN                  NaN  ...           79543
# 3                NaN                  NaN  ...          226908
# 4                NaN                  NaN  ...          226908
# ..               ...                  ...  ...             ...
# 195              NaN                  NaN  ...            8085
# 196              NaN                  NaN  ...            1589
# 197              NaN                  NaN  ...           44061
# 198              NaN                  NaN  ...           93639
# 199              NaN                  NaN  ...          115009
#
#      favourites_count   account_created_at  verified              profile_url  \
# 0               34357  2016-01-02 11:42:44     False                      NaN
# 1                1969  2019-08-14 09:08:03     False  https://t.co/h3nCpru4kN
# 2               65906  2010-06-10 19:51:21     False                      NaN
# 3              369386  2016-07-24 13:35:00     False                      NaN
# 4              369386  2016-07-24 13:35:00     False                      NaN
# ..                ...                  ...       ...                      ...
# 195             23395  2016-08-28 15:03:47     False  https://t.co/oA1wuSilpu
# 196              3576  2010-01-05 05:08:44     False                      NaN
# 197              6548  2009-09-21 04:02:11     False                      NaN
# 198             15250  2013-10-26 15:19:22     False                      NaN
# 199            117096  2015-10-20 05:21:08     False  https://t.co/cjevODiGAz
#
#                                   profile_expanded_url account_lang  \
# 0                                                  NaN          NaN
# 1                    http://instagram.com/sameerguduru          NaN
# 2                                                  NaN          NaN
# 3                                                  NaN          NaN
# 4                                                  NaN          NaN
# ..                                                 ...          ...
# 195  https://www.quora.com/profile/Mishra-Nishank?s...          NaN
# 196                                                NaN          NaN
# 197                                                NaN          NaN
# 198                                                NaN          NaN
# 199                  https://www.facebook.com/atomalok          NaN
#
#                                     profile_banner_url  \
# 0    https://pbs.twimg.com/profile_banners/46957725...
# 1    https://pbs.twimg.com/profile_banners/11615651...
# 2    https://pbs.twimg.com/profile_banners/15425798...
# 3    https://pbs.twimg.com/profile_banners/75720745...
# 4    https://pbs.twimg.com/profile_banners/75720745...
# ..                                                 ...
# 195  https://pbs.twimg.com/profile_banners/76991337...
# 196                                                NaN
# 197                                                NaN
# 198  https://pbs.twimg.com/profile_banners/21570451...
# 199  https://pbs.twimg.com/profile_banners/39996663...
#
#                                profile_background_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2    http://abs.twimg.com/images/themes/theme1/bg.png
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 195                                               NaN
# 196  http://abs.twimg.com/images/themes/theme1/bg.png
# 197  http://abs.twimg.com/images/themes/theme1/bg.png
# 198  http://abs.twimg.com/images/themes/theme1/bg.png
# 199  http://abs.twimg.com/images/themes/theme1/bg.png
#
#                                      profile_image_url
# 0    http://pbs.twimg.com/profile_images/1186240274...
# 1    http://pbs.twimg.com/profile_images/1189627750...
# 2    http://pbs.twimg.com/profile_images/1109525770...
# 3    http://pbs.twimg.com/profile_images/1101245140...
# 4    http://pbs.twimg.com/profile_images/1101245140...
# ..                                                 ...
# 195  http://pbs.twimg.com/profile_images/1158438167...
# 196  http://pbs.twimg.com/profile_images/9520296990...
# 197  http://pbs.twimg.com/profile_images/7918709064...
# 198  http://pbs.twimg.com/profile_images/1190068364...
# 199  http://pbs.twimg.com/profile_images/1142905796...
#
# [200 rows x 88 columns]

# %%
df_13 = ten_in_a_group(data_13,data_13.shape[0])
df_13 = pd.DataFrame(df_13, columns=['text'])
preprocessing(df_13,df_13.shape[0])

# %%
df_13.shape
# Out:
# (11, 1)

# %% [markdown]
# ## modi

# %%
data_14 = pd.read_csv("#modi.csv")
data_14
# Out:
#       Unnamed: 0                                               text
# 0              0  Slowly Modi is getting cornered in his own lie...
# 1              1  @barandbench see the hypocrisy of this Fuc*kin...
# 2              2  "हमें नियमित रूप से अच्छी बातें पढ़नी,उन बातों...
# 3              3  'India Our Friend': Saudi Arabia seeks 'highes...
# 4              4  'Modi Most Loved': Italian PM's gleeful praise...
# ...          ...                                                ...
# 997          997  #డిజిటల్ #INDIA\n#Modi ji 🚩\n@BJP4India https:...
# 998          998  And the award for the Greatest Corporate Scam ...
# 999          999  Such positive news on #Adani will never reach ...
# 1000        1000  #PMO #MODI #BJP \nஐயா இந்தியாவின் மிகவும் வலிம...
# 1001        1001  What else needs to be exposed before @RahulGan...
#
# [1002 rows x 2 columns]

# %%
df_14 = ten_in_a_group(data_14,data_14.shape[0])
df_14 = pd.DataFrame(df_14, columns=['text'])
preprocessing(df_14,df_14.shape[0])

# %%
df_14.shape
# Out:
# (50, 1)

# %% [markdown]
# ## NFT

# %%
data_15 = pd.read_csv("#NFT.csv")
data_15
# Out:
#       Unnamed: 0                                               text
# 0              0  "I don't need anger management, I just need pe...
# 1              1  New #NFT #Domains :\n\nvanishcode98.wallet\nli...
# 2              2  Ted #7534 \n0.02  ETH\n32.84  USD\n0xe847d8092...
# 3              3  let‘s get Mobius OAT 👇\nhttps://t.co/raXdqOupr...
# 4              4  #NFT Statistics (Real-Time)\nCollection: bored...
# ...          ...                                                ...
# 1997        1997  TRON Partners with Oraichain for AI Integratio...
# 1998        1998  TRON Partners with Oraichain for AI Integratio...
# 1999        1999  🆓Did you know that with our app you can create...
# 2000        2000  Crypto donations amplify speed and global reac...
# 2001        2001  Join @mobius_market airdrop campaign to earn y...
#
# [2002 rows x 2 columns]

# %%
df_15 = ten_in_a_group(data_15,data_15.shape[0])
df_15 = pd.DataFrame(df_15, columns=['text'])
preprocessing(df_15,df_15.shape[0])

# %%
df_15.shape
# Out:
# (169, 1)

# %% [markdown]
# ## COVID19

# %%
data_16 = pd.read_csv("#COVID19.csv")
data_16
# Out:
#       Unnamed: 0                                               text
# 0              0  @kaenchenkaffee @1900HO #IchHabeMitgemacht\n\n...
# 1              1  #Scotland mortality review \n2022 Week 09 - 20...
# 2              2  🔴L'arrêt de la France décidée par #Veran /#Mac...
# 3              3  0.23 A medida que las #vacunas #COVID19 se imp...
# 4              4  @Agenzia_Ansa Ora iniziano i piagnistei …ah no...
# ...          ...                                                ...
# 1997        1997                  #COVID19\nhttps://t.co/Kt161uV49I
# 1998        1998  Unleash the power of OneNote for your Projects...
# 1999        1999  Hey .@AshishKJha46\n1095 days - and this immun...
# 2000        2000  Studies are suggesting clearly that heart atta...
# 2001        2001  बाक़ी देश जाए भाड़ में\n मित्रकाल में बस मित्र...
#
# [2002 rows x 2 columns]

# %%
df_16 = ten_in_a_group(data_16,data_16.shape[0])
df_16 = pd.DataFrame(df_16, columns=['text'])
preprocessing(df_16,df_16.shape[0])

# %%
df_16.shape
# Out:
# (104, 1)

# %% [markdown]
# # Merging all data

# %%
lst = [df_1, df_2, df_3,df_4, df_5, df_6,df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16]
df_result= pd.concat(lst, ignore_index=True)

# %%
df_result
# Out:
#                                                    text
# 0     Ahead of AyodhyaVerdict, appeal to everyone to...
# 1     WATCH Maulana Asghar Ali Salafi, President, Ma...
# 2     For all those of the western media that were g...
# 3     Reporter's DiaryMet two kids who sell diyas on...
# 4     Just bcoz BJP got 303 seats in LS everything l...
# ...                                                 ...
# 1031  Estate Planning is not a Game of Hide and Seek...
# 1032  COVID19 Coronavirus outbreak updateTotal Cases...
# 1033  .. ? Absolutely amazing that so MANY curious s...
# 1034  The people bitching about WoodyHarrelson and h...
# 1035  Remdesivir COVID19 vaxinjured EVERYONE NEEDS T...
#
# [1036 rows x 1 columns]

# %% [markdown]
# ### Pegasus Model for Generating Summary

# %%
tokenizer = PegasusTokenizer.from_pretrained("google/pegasus-xsum")
model = PegasusForConditionalGeneration.from_pretrained("google/pegasus-xsum")

# %%
def summary_generator(gen_sum):
    tokens = tokenizer(gen_sum, truncation=True, padding="longest", return_tensors="pt")
    summary = model.generate(**tokens,min_new_tokens=256,no_repeat_ngram_size=1)
    
    temp=""
    temp=tokenizer.decode(summary[0])
    return temp

# %%
n = df_result.shape[0]
main_df = []
for i in tqdm(range (n), total=n):
    temp = ""
    temp = summary_generator(df_result['text'][i])
    main_df = main_df.append(temp)
# Out:
#   0%|          | 0/1036 [00:00<?, ?it/s]

# %%
main_df
# Out:
# '<pad>"My essay on the AYODHYAVERDICT welcome Hon Supreme Court\'s AyodhyaVerdicton Sri Ram Janmbhoomi, I appeal to people of all religionsto honour its verdict and maintain peace with each other," wrote Abhishek Manu Singhvi in a Facebook post after he was granted special leave</s><pad>Maulana Asghar Ali Salafi, President of Markazi Jamiat Ahle Hadees Hind has said that the Ayodhya verdict is a "victory for Hindus and Muslims" as he met National Security Adviser (NSA) Ajit Doval at his residence in Delhi on Thursday morning to discuss India\'s</s><pad>"I am an Indian, I want MandirMasjid issues to be buried deep down and realIssues like price rise... unemployment.... social security.... Transgenders rights etc are addressed." - Amartya13 saileenaS AYODHYAVERDICTIndian Muslims Like Me Have Been Very Vocal amp Happy</s><pad>A day after the Ayodhya verdict, here\'s a round-up of what people have to say about it on social media and other platforms - from those who are very vocal in their support for BAPS (Babri Masjid Action Committee), which was opposed by Hindu nationalist groups like Bharatiya Janata</s><pad>Just bcoz BJP got 303 seats in LS everything looks hunky dory, JDU amp ShivSena would have been the first ones to jumpthe NDA ship for greener pasture. "Problem is notfor a Land For Domination"HinduismBJP RSS - The Corpse Is Not Showing Any Resistance To</s><pad>Watch the live coverage of Supreme Court\'s verdict on Ayodhya dispute as it is read out by Chief Justice Dipak Misra in a packed courtroom, including senior lawyers and prominent Hindu leaders like Maulana Asghar Ali Salafi from Markazi Jamiat Ahle Hadees Hind (MMAH), former</s><pad>Watch the full episode of TVNewsance here a step to impress Sonia Gandhiamp Congress for their unholy support, Shiv Sena can publish The National Herald pieces questioning Supreme Court\'s AYODHYAVERDICT amp maligning Hindus V Have Wholeheartedly Congratulated Our Fellow Indian Counterparts On Rightfully Getting What</s><pad>As a step to impress Sonia Gandhiamp Congress for their unholy support, Shiv Sena can publish the National Herald pieces questioning Supreme Court\'s AYODHYAVERDICT amp maligning Hindus Shri Ram temple will be built in Ayodhya - here are some excerpts from social media posts by people who have been reacting</s><pad>May everyone be happy, I pray for peace and harmony AYODHYAVERDICTJust bcoz BJP got 303 seats in LS everything looks hunky dory.May you all have a great time on this wonderful occasion of India\'s 70th Independence Day - the day when our country was partitioned into two</s><pad>When the Babri Masjid was here in favour of Muslims, we all must have been curious to know how a mosque could be built on land that is now known as Ayodhya and what it would mean for our country\'s future if Hindus were given full control over its construction. may everyone enjoy peaceful coexistence</s><pad>As usual Kannada newspapers covered AYODHYAVERDICT bcoz BJP got 303 seats in LS everything looks hunky dory, JDU amp ShivSena would have been the first ones to jumpthe NDA ship for greener pasture. :D - I\'m a big fan of Prime Minister Narendra Modi</s><pad>As a step to impress Sonia Gandhiamp Congress for their unholy support, Shiv Sena can publish the National Herald pieces questioning Supreme Court\'s AYODHYAVERDICT amp maligning Hindus Shivanand ShindeMaharashtraBQDebates What Senior Advocate Sajan poovayya calls an unwarranted approach that</s><pad>India beat Australia by eight wickets on day three of the third and final Test at The Oval to take an unassailable 3-0 lead in their four-match series. <unk>Copyright (c) Postmedia News Original source article: INDvAUS BorderGavaskarTrophy2023 - Day 3</s><pad>How bad was Dharamshala that India lost the 2nd Test against Australia and now they are facing a 3-0 series whitewash in their own backyard, thanks to some poor batting on day 1 of third test at Indore. :money_bag]: Cricket INDvAUS one is talking about incompetent stroking ...

# %%
y=main_df.split("</s>")

# %%
type(y)
# Out:
# list

# %%
df_result['text']
# Out:
# 0       Ahead of AyodhyaVerdict, appeal to everyone to...
# 1       WATCH Maulana Asghar Ali Salafi, President, Ma...
# 2       For all those of the western media that were g...
# 3       Reporter's DiaryMet two kids who sell diyas on...
# 4       Just bcoz BJP got 303 seats in LS everything l...
#                               ...
# 1031    Estate Planning is not a Game of Hide and Seek...
# 1032    COVID19 Coronavirus outbreak updateTotal Cases...
# 1033    .. ? Absolutely amazing that so MANY curious s...
# 1034    The people bitching about WoodyHarrelson and h...
# 1035    Remdesivir COVID19 vaxinjured EVERYONE NEEDS T...
# Name: text, Length: 1036, dtype: object

# %%
x=[]
for t in df_result['text']:
    x.append(t)

# %%
y.pop()
# Out:
# ''

# %%
len(y)
# Out:
# 1036

# %%
dict={'x':x,'y':y}

# %%
pd.DataFrame(dict).to_csv("dataset.csv")

# %%
final_df = pd.read_csv("dataset.csv")
final_df
# Out:
#       Unnamed: 0                                                  x  \
# 0              0  Ahead of AyodhyaVerdict, appeal to everyone to...
# 1              1  WATCH Maulana Asghar Ali Salafi, President, Ma...
# 2              2  For all those of the western media that were g...
# 3              3  Reporter's DiaryMet two kids who sell diyas on...
# 4              4  Just bcoz BJP got 303 seats in LS everything l...
# ...          ...                                                ...
# 1031        1031  Estate Planning is not a Game of Hide and Seek...
# 1032        1032  COVID19 Coronavirus outbreak updateTotal Cases...
# 1033        1033  .. ? Absolutely amazing that so MANY curious s...
# 1034        1034  The people bitching about WoodyHarrelson and h...
# 1035        1035  Remdesivir COVID19 vaxinjured EVERYONE NEEDS T...
#
#                                                       y
# 0     <pad>"My essay on the AYODHYAVERDICT welcome H...
# 1     <pad>Maulana Asghar Ali Salafi, President of M...
# 2     <pad>"I am an Indian, I want MandirMasjid issu...
# 3     <pad>A day after the Ayodhya verdict, here's a...
# 4     <pad>Just bcoz BJP got 303 seats in LS everyth...
# ...                                                 ...
# 1031  <pad>The World Health Organization (WHO) has c...
# 1032  <pad>The number of people who have died from t...
# 1033  <pad>The Covid19 lab leak theory is back in th...
# 1034  <pad>Here's a look back at some of the key sto...
# 1035  <pad>In Case You Missed It: a round-up of inte...
#
# [1036 rows x 3 columns]

# %%
def removepad(t):
    t.replace("<pad>","")

# %%
final_df['y'].apply(removepad)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 1031    None
# 1032    None
# 1033    None
# 1034    None
# 1035    None
# Name: y, Length: 1036, dtype: object

# %%
final_df
# Out:
#       Unnamed: 0                                                  x  \
# 0              0  Ahead of AyodhyaVerdict, appeal to everyone to...
# 1              1  WATCH Maulana Asghar Ali Salafi, President, Ma...
# 2              2  For all those of the western media that were g...
# 3              3  Reporter's DiaryMet two kids who sell diyas on...
# 4              4  Just bcoz BJP got 303 seats in LS everything l...
# ...          ...                                                ...
# 1031        1031  Estate Planning is not a Game of Hide and Seek...
# 1032        1032  COVID19 Coronavirus outbreak updateTotal Cases...
# 1033        1033  .. ? Absolutely amazing that so MANY curious s...
# 1034        1034  The people bitching about WoodyHarrelson and h...
# 1035        1035  Remdesivir COVID19 vaxinjured EVERYONE NEEDS T...
#
#                                                       y
# 0     <pad>"My essay on the AYODHYAVERDICT welcome H...
# 1     <pad>Maulana Asghar Ali Salafi, President of M...
# 2     <pad>"I am an Indian, I want MandirMasjid issu...
# 3     <pad>A day after the Ayodhya verdict, here's a...
# 4     <pad>Just bcoz BJP got 303 seats in LS everyth...
# ...                                                 ...
# 1031  <pad>The World Health Organization (WHO) has c...
# 1032  <pad>The number of people who have died from t...
# 1033  <pad>The Covid19 lab leak theory is back in th...
# 1034  <pad>Here's a look back at some of the key sto...
# 1035  <pad>In Case You Missed It: a round-up of inte...
#
# [1036 rows x 3 columns]

# %%
final_df['x'][600]
# Out:
# 'Newsleaders भोपाल  मप्र की ख़बरें,प्रदेश में क्या हुआ दिनभर,देखिए न्यूज़लीडर्स पर ताजा अपडेटNewsleaders Bhopal Indore\xa0 MadhyaPardesh India Khargone Barwani ChouhanShivraj BJP Kamalnath\xa0Congress Jays bjp4mp Johar जयस Budget2023  someone tell us more about the one time 1.4bil set aside for somethimg notaslushfund  for govt use after April 1, just before the election? ablegnevertrustUCPbudget2023DSRFcanada thoughts on the Budget2023 It sounds like increasing therapy. Any creative plans for this, spring break camp, summer camp? Im still not using all of my at home funding.This AlbertaUCP Budget2023 gives an opportunity to the abndpcaucus to be the fiscal ‘conservative election option.  Slow down and target spending to really help ordinary Albertans. The UCP is recklesswithrevenue abpoliDont forget that the petrol cap and subsidies will also be removed before the Budget2023Sunaks next job is to tackle the looming disaster of another hike in energy bills come April. 20 :flushed_face:The rabbit in the hat for Hunts Budget2023 ? Has MartinSLewis read the runes right? :thumbs_up:And just in time for the May elections.International aid agencies ask for more money in letter to Freeland ahead of budget  budget2023Budget 2023 ensures we are growing Alberta for the future We are advancing our skilled jobs initiatives, making record investments in health care and education, along with keeping Alberta affordable.Learn more Budget2023 abpoli ableg  daisymeylands, RichHallCA, chaitanyakumar and me in digesting what the Budget2023 means for consumers and the energy sectorBudget2023 has prioritised capital expenditure for addressing the needs of public infrastructure along with some focussed welfare initiatives in crucial sectors, notes AmbarKumarGhos1 '

# %%
final_df['y'][600]
# Out:
# "<pad>Alberta's Budget2023 has been met with a mixed response on social media, as many are wondering what the government is planning to do about rising energy bills and falling oil prices ahead of elections in May. The UCPis recklesswith abpoliDont forget that there will also be another fuel tax increase"
